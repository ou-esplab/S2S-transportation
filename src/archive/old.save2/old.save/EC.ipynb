# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import itertools
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from scipy import stats

# %%
sq = pd.read_csv('processed_swe_data.csv')

# %%
print("Columns in the DataFrame:", sq.columns.tolist())
# Out:
# Columns in the DataFrame: ['YEAR', 'MONTH', 'snow_water_equivalent_AL', 'snow_water_equivalent_AR', 'snow_water_equivalent_AZ', 'snow_water_equivalent_CA', 'snow_water_equivalent_CO', 'snow_water_equivalent_CT', 'snow_water_equivalent_DC', 'snow_water_equivalent_DE', 'snow_water_equivalent_FL', 'snow_water_equivalent_GA', 'snow_water_equivalent_IA', 'snow_water_equivalent_ID', 'snow_water_equivalent_IL', 'snow_water_equivalent_IN', 'snow_water_equivalent_KS', 'snow_water_equivalent_KY', 'snow_water_equivalent_LA', 'snow_water_equivalent_MA', 'snow_water_equivalent_MD', 'snow_water_equivalent_ME', 'snow_water_equivalent_MI', 'snow_water_equivalent_MN', 'snow_water_equivalent_MO', 'snow_water_equivalent_MS', 'snow_water_equivalent_MT', 'snow_water_equivalent_NC', 'snow_water_equivalent_ND', 'snow_water_equivalent_NE', 'snow_water_equivalent_NH', 'snow_water_equivalent_NJ', 'snow_water_equivalent_NM', 'snow_water_equivalent_NV', 'snow_water_equivalent_NY', 'snow_water_equivalent_OH', 's
# ...

# %%
# Filter rows where snow_water_equivalent_data is 'NE'
ne_data = sq

# Check the range of snow_water_equivalent
if not ne_data.empty:
    min_value = ne_data['YEAR'].min()
    max_value = ne_data['YEAR'].max()
    print(f"Range of 'snow_water_equivalent' for 'NE': {min_value} to {max_value}")
else:
    print("No rows found with 'snow_water_equivalent_data' equal to 'NE'.")
# Out:
# Range of 'snow_water_equivalent' for 'NE': 2003 to 2020
