# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import itertools
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from scipy import stats
import seaborn as sns
import dask
import dask.dataframe as dd
from dask.distributed import Client
from dask.distributed import LocalCluster

# %%
sq = dd.read_csv('combined_snow_water.csv')
precip_data = pd.read_csv('combined_ENSO_highresprecip.csv')
df = pd.read_csv('DATABASE.csv')

# %%
print(sq.columns)
print(precip_data.columns)
print(df.columns)
# Out:
# Index(['X', 'Y', 'Value', 'Year', 'Month'], dtype='object')
# Index(['YEAR', 'Month', 'ENSO_Value', 'Year-Month', 'Precip_Anomaly_ID',
#        'Precip_Anomaly_KY', 'Precip_Anomaly_DE', 'Precip_Anomaly_FL',
#        'Precip_Anomaly_PA', 'Precip_Anomaly_RI', 'Precip_Anomaly_IA',
#        'Precip_Anomaly_WA', 'Precip_Anomaly_WV', 'Precip_Anomaly_NC',
#        'Precip_Anomaly_MO', 'Precip_Anomaly_AL', 'Precip_Anomaly_AZ',
#        'Precip_Anomaly_MN', 'Precip_Anomaly_TN', 'Precip_Anomaly_NV',
#        'Precip_Anomaly_OR', 'Precip_Anomaly_TX', 'Precip_Anomaly_VT',
#        'Precip_Anomaly_MI', 'Precip_Anomaly_NE', 'Precip_Anomaly_CT',
#        'Precip_Anomaly_ND', 'Precip_Anomaly_CA', 'Precip_Anomaly_VA',
#        'Precip_Anomaly_NJ', 'Precip_Anomaly_AR', 'Precip_Anomaly_WI',
#        'Precip_Anomaly_UT', 'Precip_Anomaly_ME', 'Precip_Anomaly_LA',
#        'Precip_Anomaly_PRCP', 'Precip_Anomaly_CO', 'Precip_Anomaly_NH',
#        'Precip_Anomaly_MS', 'Precip_Anomaly_MD', 'Precip_Anomaly_WY',
#        'Precip_Anomaly_OH', 'Precip_Anomaly_MA', 'Precip_Anomaly_NM',
#        'Precip_Anomaly_OK', 'Precip_Anomaly_MT', 'Precip_Anomaly_NY',
#        'Precip_Anomaly_SC', 'Precip_Anomaly_KS', 'Precip_Anomaly_IL',
#        'Precip_Anomaly_IN', 'Precip_Anomaly_GA', 'Precip_Anomaly_SD'],
#       dtype='object')
# Index(['STATE', 'COUNTY', 'CITY', 'MONTH', 'DAY', 'YEAR', 'HOUR', 'MINUTE',
#        'WEATHER', 'FATALS', 'DAY_WEEK', 'SST_value'],
#       dtype='object')
