# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import regionmask
import os
import sys

import geopandas as gp
import rioxarray
from shapely.geometry import mapping


import warnings

# %%
files= '/data/esplab/aelyoussoufi/swe.2003-12-01.2020-12-31.NE.nc'

# %%
ds=xr.open_mfdataset(files)

# %%
ds
# Out:
# <xarray.Dataset> Size: 260MB
# Dimensions:                (time: 52, lat: 841, lon: 744)
# Coordinates:
#   * time                   (time) object 416B 2003-12-01 00:00:00 ... 2020-12...
#   * lat                    (lat) float64 7kB 42.0 42.0 42.01 ... 48.99 49.0
#   * lon                    (lon) float64 6kB -117.2 -117.2 ... -111.1 -111.0
#     longitude              (lon) float64 6kB dask.array<chunksize=(744,), meta=np.ndarray>
#     dayofyear              (time) int64 416B dask.array<chunksize=(52,), meta=np.ndarray>
# Data variables:
#     snow_water_equivalent  (time, lat, lon) float64 260MB dask.array<chunksize=(52, 841, 744), meta=np.ndarray>

# %%
import pandas as pd

# Load the CSV file
file_path = 'swe.2003-12-01.2020-12-31.CA.csv'
df = pd.read_csv(file_path)

# Find the minimum and maximum values for snow_water_equivalent
min_value = df['snow_water_equivalent'].min()
max_value = df['snow_water_equivalent'].max()

# Print the range
print(f"Range of 'snow_water_equivalent': ({min_value}, {max_value})")

# Optional: Print some additional statistics
print("\nAdditional statistics:")
print(df['snow_water_equivalent'].describe())
# Out:
# Range of 'snow_water_equivalent': (-779.5509194404848, 1588.21557863297)
#
# Additional statistics:
# count    3.077678e+07
# mean    -2.512905e-09
# std      5.867664e+01
# min     -7.795509e+02
# 25%     -3.443930e-01
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.588216e+03
# Name: snow_water_equivalent, dtype: float64
