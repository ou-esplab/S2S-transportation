# %%
import pandas as pd

# %%
df=pd.read_csv('../data/FARS_CLIMATEIndices.csv')

# %%
df
# Out:
#         STATE  COUNTY  CITY  MONTH  DAY  YEAR  HOUR  MINUTE  WEATHER  FATALS  \
# 0           1      89  2225      1    8  1975    13      20        2       1
# 1           1      69  2961      1    4  1975     1      15        2       1
# 2           1     101  2130      1    3  1975    17      44        2       1
# 3           1     117     0      1   10  1975    15      20        2       1
# 4           1      83   120      1    8  1975    14      37        2       1
# ...       ...     ...   ...    ...  ...   ...   ...     ...      ...     ...
# 200825     56      37     0      2   21  2021    12      55       11       1
# 200826     56      43     0      4   19  2021    10      30        4       1
# 200827     56      33     0      7    3  2021    16       3        2       2
# 200828     56       5   310     10   19  2021    23       0        4       1
# 200829     56      21   100     10   12  2021    21      16        4       1
#
#         DAY_WEEK  SST_value
# ...
